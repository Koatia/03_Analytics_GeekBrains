# %% [markdown]
# ### Задание 1
#
# Постройте графики для приведенных наборов данных. Найдите коэффициенты для линии
# регрессии и коэффициенты детерминации. Что вы замечаете? Нанесите на график модель
# линейной регрессии

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
x1 = np.array([30, 30, 40, 40])
y1 = np.array([37, 47, 50, 60])

x2 = np.array([30, 30, 40, 40, 20, 20, 50, 50])
y2 = np.array([37, 47, 50, 60, 25, 35, 62, 72])

x3 = np.array([30, 30, 40, 40, 20, 20, 50, 50, 10, 10, 60, 60])
y3 = np.array([37, 47, 50, 60, 25, 35, 62, 72, 13, 23, 74, 84])

# %%
plt.scatter(x1, y1)

x1 = x1.reshape(-1, 1)
model = LinearRegression()
model.fit(x1, y1)

r = model.score(x1, y1)
print(f"Коэффициент детерминации: {r}")

a = model.intercept_
b = model.coef_
print(f"y = {a} + {b} * x")

plt.plot(x1, a + b * x1, color="red")
# Out:
# Коэффициент детерминации: 0.6282527881040892
# y = 3.0 + [1.3] * x

# %%
plt.scatter(x2, y2)

x2 = x2.reshape(-1, 1)
model = LinearRegression()
model.fit(x2, y2)

r = model.score(x2, y2)
print(f"Коэффициент детерминации: {r}")

a = model.intercept_
b = model.coef_
print(f"y = {a} + {b} * x")

plt.plot(x2, a + b * x2, color="red")
# Out:
# Коэффициент детерминации: 0.8846950517836594
# y = 5.1000000000000085 + [1.24] * x

# %%
plt.scatter(x3, y3)

x3 = x3.reshape(-1, 1)
model = LinearRegression()
model.fit(x3, y3)

r = model.score(x3, y3)
print(f"Коэффициент детерминации: {r}")

a = model.intercept_
b = model.coef_
print(f"y = {a} + {b} * x")

plt.plot(x3, a + b * x3, color="red")
# Out:
# Коэффициент детерминации: 0.9459101071621309
# y = 5.600000000000016 + [1.22571429] * x

# %% [markdown]
# ### Задание 2
#
# На 8 уроке мы строили графики приведенных ниже данных.
# Для какого графика можно использовать модель линейной регрессии?

# %%
x1 = np.array([10, 8, 13, 9, 11, 14, 6, 4, 12, 7, 5])
y1 = np.array([8.04, 6.95, 7.58, 8.81, 8.33, 9.96, 7.24, 4.26, 10.84, 4.82, 5.68])

x2 = np.array([10, 8, 13, 9, 11, 14, 6, 4, 12, 7, 5])
y2 = np.array([9.14, 8.14, 8.74, 8.77, 9.26, 8.10, 6.13, 3.10, 9.13, 7.26, 4.74])

x3 = np.array([10, 8, 13, 9, 11, 14, 6, 4, 12, 7, 5])
y3 = np.array([7.46, 6.77, 12.74, 7.11, 7.81, 8.84, 6.08, 5.39, 8.15, 6.42, 5.73])

x4 = np.array([8, 8, 8, 8, 8, 8, 8, 19, 8, 8, 8])
y4 = np.array([6.58, 5.76, 7.71, 8.84, 8.47, 7.04, 5.25, 12.5, 5.56, 7.91, 6.89])

x5 = np.array([10, 8, 13, 9, 11, 14, 6, 4, 12, 7, 5, 15, 16, 18])
y5 = np.array(
    [9.14, 8.14, 8.74, 8.77, 9.26, 8.10, 6.13, 3.10, 9.13, 7.26, 4.74, 6.5, 5, 2.9]
)

# %%
plt.scatter(x=x1, y=y1)

x1 = x1.reshape(-1, 1)
model = LinearRegression()
model.fit(x1, y1)

r = model.score(x1, y1)
print(f"Коэффициент детерминации: {r}")

a = model.intercept_
b = model.coef_
print(f"y = {a} + {b} * x")

plt.plot(x1, a + b * x1, color="red")
# Out:
# Коэффициент детерминации: 0.6665424595087748
# y = 3.0000909090909094 + [0.50009091] * x

# %%
plt.scatter(x=x2, y=y2)

# %%
plt.scatter(x=x3, y=y3)

x3 = x3.reshape(-1, 1)
model = LinearRegression()
model.fit(x3, y3)

r = model.score(x3, y3)
print(f"Коэффициент детерминации: {r}")

a = model.intercept_
b = model.coef_
print(f"y = {a} + {b} * x")

plt.plot(x3, a + b * x3, color="red")
# Out:
# Коэффициент детерминации: 0.6663240410665592
# y = 3.002454545454545 + [0.49972727] * x

# %%
plt.scatter(x=x4, y=y4)

x4 = x4.reshape(-1, 1)
model = LinearRegression()
model.fit(x4, y4)

r = model.score(x4, y4)
print(f"Коэффициент детерминации: {r}")

a = model.intercept_
b = model.coef_
print(f"y = {a} + {b} * x")

plt.plot(x4, a + b * x4, color="red")
# Out:
# Коэффициент детерминации: 0.6667072568984653
# y = 3.0017272727272726 + [0.49990909] * x

# %%
plt.scatter(x=x5, y=y5)

# %% [markdown]
# #### Домашнее задание 1
#
# _Даны значения величины заработной платы заемщиков банка (zp) и значения их поведенческого кредитного скоринга (ks). Используя математические операции, посчитать коэффициенты линейной регрессии, приняв за X заработную плату (то есть, zp - признак), а за y - значения скорингового балла (то есть, ks - целевая переменная). Произвести расчет как с использованием intercept, так и без._

# %%
# Данные
zp = np.array([35, 45, 190, 200, 40, 70, 54, 150, 120, 110])
ks = np.array([401, 574, 874, 919, 459, 739, 653, 902, 746, 832])

plt.scatter(x=zp, y=ks)

# Создаем и обучаем модель линейной регрессии с интерсептом
model = LinearRegression()
zp = zp.reshape(-1, 1)
model.fit(zp, ks)

r = model.score(zp, ks)
print(f"Коэффициент детерминации: {r}")

a = model.intercept_
b = float(model.coef_)
print(f"Коэффициенты линейной регрессии: {a}, {b}")
print(f"Итоговое уравнение регрессии: y = {a:0.2f} + {b:0.2f} * x")

plt.plot(zp, a + b * zp, color="red")
# Out:
# Коэффициент детерминации: 0.7876386635293685
# Коэффициенты линейной регрессии: 444.1773573243595, 2.6205388824027662
# Итоговое уравнение регрессии: y = 444.18 + 2.62 * x
# /tmp/ipykernel_692/3552246451.py:16: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   b = float(model.coef_)

# %%
plt.scatter(x=zp, y=ks)

# Создаем и обучаем модель линейной регрессии без интерсепта
model = LinearRegression(fit_intercept=False)
zp = zp.reshape(-1, 1)
model.fit(zp, ks)

r = model.score(zp, ks)
print(f"Коэффициент детерминации: {r}")

a = model.intercept_
b = float(model.coef_)
print(f"Коэффициенты линейной регрессии: {a}, {b}")
print(f"Итоговое уравнение регрессии: y = {b:0.2f} * x")

plt.plot(zp, a + b * zp, color="red")
# Out:
# Коэффициент детерминации: -0.8549037531632884
# Коэффициенты линейной регрессии: 0.0, 5.889820420132688
# Итоговое уравнение регрессии: y = 5.89 * x
# /tmp/ipykernel_692/3281121674.py:12: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   b = float(model.coef_)

# %% [markdown]
# #### Домашнее задание 2
#
# **_Посчитать коэффициент линейной регрессии при заработной плате (zp), используя градиентный спуск (без intercept)._**

# %%
# Данные
zp = np.array([35, 45, 190, 200, 40, 70, 54, 150, 120, 110])
ks = np.array([401, 574, 874, 919, 459, 739, 653, 902, 746, 832])

# Параметры градиентного спуска
alpha = 0.0001  # Шаг обучения
n_iterations = 10000  # Количество итераций
m = len(zp)  # Количество наблюдений

# Начальное значение коэффициента
beta_1 = 0

# Градиентный спуск
for _ in range(n_iterations):
    gradient = (1 / m) * np.sum((beta_1 * zp - ks) * zp)
    beta_1 -= alpha * gradient

print(f"Коэффициент наклона линейной регрессии: {beta_1}")
print(f"Итоговое уравнение регрессии: y = {beta_1:0.2f} * x")
# Out:
# Коэффициент наклона линейной регрессии: 5.889820420132689
# Итоговое уравнение регрессии: y = 5.89 * x

# %% [markdown]
# #### Домашнее задание 3
#
# **_Произвести вычисления как в пункте 2, но с вычислением intercept. Учесть, что изменение коэффициентов должно производиться на каждом шаге одновременно (то есть изменение одного коэффициента не должно влиять на изменение другого во время одной итерации)._**

# %%
# Данные
zp = np.array([35, 45, 190, 200, 40, 70, 54, 150, 120, 110])
ks = np.array([401, 574, 874, 919, 459, 739, 653, 902, 746, 832])

# Параметры градиентного спуска
alpha = 0.0001  # Шаг обучения
n_iterations = 1000000  # Количество итераций
m = len(zp)  # Количество наблюдений

# Начальные значения коэффициентов
beta_0 = 0
beta_1 = 0

# Градиентный спуск
for _ in range(n_iterations):
    y_pred = beta_0 + beta_1 * zp
    error = y_pred - ks

    beta_0_gradient = (1 / m) * np.sum(error)
    beta_1_gradient = (1 / m) * np.sum(error * zp)

    beta_0 -= alpha * beta_0_gradient
    beta_1 -= alpha * beta_1_gradient


print(f"Коэффициенты линейной регрессии: {beta_0}, {beta_1}")
print(f"Итоговое уравнение регрессии: y = {beta_0:0.2f} + {beta_1:0.2f} * x")
# Out:
# Коэффициенты линейной регрессии: 444.177357319993, 2.6205388824349054
# Итоговое уравнение регрессии: y = 444.18 + 2.62 * x
