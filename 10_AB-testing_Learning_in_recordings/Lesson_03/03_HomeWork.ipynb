# %%
import numpy as np
import pandas as pd

import scipy

import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme()

# %% [markdown]
# <p style="align: center;"><img align=center src="https://mailfit.com/wp-content/uploads/2019/11/lego-5.png"  width=900></p>
# <h1 style="text-align: center;"><b>«Домашняя работа»</b></h3>

# %%
data_path = "https://raw.githubusercontent.com/a-milenkin/mipt_data_science_2021/main/data/people_data_clustering.csv"
data = pd.read_csv(data_path, index_col=0)
print("Размеры датасета", data.shape)
data.head()
# Out:
# Размеры датасета (6000, 9)
#     was_married  children        salary  sex   age     profession  \
# id
# 0             1       4.0  4.420530e+07    1  82.0       Engineer
# 1             1       2.0  1.737490e+08    1  32.0         Doctor
# 2             1       6.0  2.489055e+08    1  14.0  Entertainment
# 3             0       1.0  1.268718e+08    0  10.0         Lawyer
# 4             1       9.0  8.596042e+07    1  99.0         Artist
#
#        home_cost  drive_info  happyness
# id
# 0   1.003674e+07         NaN   0.727499
# 1   1.014051e+07         0.0   0.383234
# 2   1.043318e+07         NaN   0.432142
# 3   1.004299e+07         NaN   0.377987
# 4   1.021908e+07         NaN   0.657579

# %% [markdown]
# <div class="alert alert-info">
# <b>Про Датасет</b>
#
# Датасет представляет собой информацию по жителям некоторого города.
#
# * `was_married` - Был ли когда-либо женат/замужем
# * `children` - Количество детей
# * `salary` - Уровень зарплаты
# * `sex` - Пол (0 - женщина, 1 - мужчина)
# * `age` - Возраст
# * `home_cost` - Сумарная стоимость жилья/недвижимости
# * `Professon` - Профессия
# * `drive_info` - Есть ли водительские права
# * `happyness` - уровень счастья по результатам опроса
#
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Задание</b>
#
# Изучить датасет, выполнить задания и проверить некоторые гипотезы, предложенные ниже, используя только визуализацию.

# %% [markdown]
# # Изучение датасета
# * Какие признаки численные?
# * Какие признаки категориальные?
# * Какие признаки имеют нормальное распределение?
# * Какие признаки бессмысленные?

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6000 entries, 0 to 499
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   was_married  6000 non-null   int64
#  1   children     6000 non-null   float64
#  2   salary       6000 non-null   float64
#  3   sex          6000 non-null   int64
#  4   age          6000 non-null   float64
#  5   profession   6000 non-null   object
#  6   home_cost    6000 non-null   float64
#  7   drive_info   3230 non-null   float64
#  8   happyness    6000 non-null   float64
# dtypes: float64(6), int64(2), object(1)
# memory usage: 468.8+ KB

# %% [markdown]
# <div class="alert alert-dark">
#
# В датасете 9 признаков. Они имеют следующие типы данных:
#
# - **Численные признаки (float64 и int64):**
#   - `was_married` (int64)
#   - `children` (float64)
#   - `salary` (float64)
#   - `sex` (int64)
#   - `age` (float64)
#   - `home_cost` (float64)
#   - `drive_info` (float64)
#   - `happyness` (float64)
#
# - **Категориальные признаки:**
#   - `profession` (object)

# %%
print(data["was_married"].value_counts())
print("\n", data["sex"].value_counts())
print("\n", data["drive_info"].value_counts())
# Out:
# was_married
# 1    5052
# 0     948
# Name: count, dtype: int64
#
#  sex
# 1    3971
# 0    2029
# Name: count, dtype: int64
#
#  drive_info
# 1.0    2355
# 0.0     875
# Name: count, dtype: int64

# %% [markdown]
# <div class="alert alert-dark">
#
# Признаки `was_married`, `sex` и `drive_info` принимают одно из двух значений - **не имеют нормального распределения**

# %%
print("`children` - Количество детей")
plt.figure(figsize=(12, 6))
# Одна строка, два столбца. Текущая ячейка - 1
plt.subplot(1, 2, 1)
plt.hist(data["children"], alpha=0.8)
plt.title("Гистограмма значений")

# Одна строка, два столбца. Текущая ячейка - 2
plt.subplot(1, 2, 2)
plt.boxplot(data["children"])
plt.title("Боксплот")
# Out:
# `children` - Количество детей
# Text(0.5, 1.0, 'Боксплот')

# %% [markdown]
# <div class="alert alert-dark">
#
# Признак `children` не имеет нормального распределения

# %%
print("`salary` - Уровень зарплаты")
plt.figure(figsize=(12, 6))
# Одна строка, два столбца. Текущая ячейка - 1
plt.subplot(1, 2, 1)
plt.hist(data["salary"], bins=50, alpha=0.8)
plt.title("Гистограмма значений")

# Одна строка, два столбца. Текущая ячейка - 2
plt.subplot(1, 2, 2)
plt.boxplot(data["salary"])
plt.title("Боксплот")
# Out:
# `salary` - Уровень зарплаты
# Text(0.5, 1.0, 'Боксплот')

# %% [markdown]
# <div class="alert alert-dark">
#
# Признак `salary` не имеет нормального распределения

# %%
print("`age` - Возраст")
plt.figure(figsize=(12, 6))
# Одна строка, два столбца. Текущая ячейка - 1
plt.subplot(1, 2, 1)
plt.hist(data["age"], bins=50, alpha=0.8)
plt.title("Гистограмма значений")

# Одна строка, два столбца. Текущая ячейка - 2
plt.subplot(1, 2, 2)
plt.boxplot(data["age"])
plt.title("Боксплот")
# Out:
# `age` - Возраст
# Text(0.5, 1.0, 'Боксплот')

# %% [markdown]
# <div class="alert alert-dark">
#
# Признак `age` не имеет нормального распределения

# %%
print("`home_cost` - Сумарная стоимость жилья/недвижимости")
plt.figure(figsize=(12, 6))
# Одна строка, два столбца. Текущая ячейка - 1
plt.subplot(1, 2, 1)
plt.hist(data["home_cost"], bins=100, alpha=0.8)
plt.title("Гистограмма значений")

# Одна строка, два столбца. Текущая ячейка - 2
plt.subplot(1, 2, 2)
plt.boxplot(data["home_cost"])
plt.title("Боксплот")
# Out:
# `home_cost` - Сумарная стоимость жилья/недвижимости
# Text(0.5, 1.0, 'Боксплот')

# %% [markdown]
# <div class="alert alert-dark">
#
# Признак `home_cost` имеет нормальное распределение и несколько выбросов

# %%
print("`happyness` - уровень счастья по результатам опроса")
plt.figure(figsize=(12, 6))
# Одна строка, два столбца. Текущая ячейка - 1
plt.subplot(1, 2, 1)
plt.hist(data["happyness"], bins=100, alpha=0.8)
plt.title("Гистограмма значений")

# Одна строка, два столбца. Текущая ячейка - 2
plt.subplot(1, 2, 2)
plt.boxplot(data["happyness"])
plt.title("Боксплот")
# Out:
# `happyness` - уровень счастья по результатам опроса
# Text(0.5, 1.0, 'Боксплот')

# %% [markdown]
# <div class="alert alert-dark">
#
# Признак `happyness` имеет нормальное распределение и несколько выбросов

# %%
data.describe()
# Out:
#        was_married     children        salary          sex          age  \
# count  6000.000000  6000.000000  6.000000e+03  6000.000000  6000.000000
# mean      0.842000     2.887167  8.463445e+07     0.661833    31.776667
# std       0.364771     2.850285  8.022130e+07     0.473125    32.546372
# min       0.000000     0.000000  1.765712e+06     0.000000     2.000000
# 25%       1.000000     1.000000  1.092669e+07     0.000000    10.000000
# 50%       1.000000     2.000000  4.301600e+07     1.000000    17.000000
# 75%       1.000000     4.000000  1.588318e+08     1.000000    32.000000
# max       1.000000     9.000000  3.459271e+08     1.000000   100.000000
#
#           home_cost   drive_info    happyness
# count  6.000000e+03  3230.000000  6000.000000
# mean   1.019184e+07     0.729102     0.460160
# std    3.120066e+05     0.444492     0.153727
# min    9.824378e+06     0.000000     0.000000
# 25%    1.009639e+07     0.000000     0.351787
# 50%    1.017716e+07     1.000000     0.451588
# 75%    1.026920e+07     1.000000     0.562556
# max    2.065792e+07     1.000000     1.000000

# %% [markdown]
# <div class="alert alert-dark">
#
# Признак `drive_info` может быть бессмысленным, так как заполнен только на половину (3230 значений из 6000)

# %% [markdown]
# # Чистка датасета
# * Есть ли дубли в данных? Если есть - удалить их (`drop_duplicates`).
# * Есть ли пропуски в данных? Если есть - удалить столбцы, в которых они есть. (`dropna()`)
# * Найти и удалить выбросы по признаку `home_cost`. Сколько их?

# %%
df = data.drop_duplicates()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6000 entries, 0 to 499
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   was_married  6000 non-null   int64
#  1   children     6000 non-null   float64
#  2   salary       6000 non-null   float64
#  3   sex          6000 non-null   int64
#  4   age          6000 non-null   float64
#  5   profession   6000 non-null   object
#  6   home_cost    6000 non-null   float64
#  7   drive_info   3230 non-null   float64
#  8   happyness    6000 non-null   float64
# dtypes: float64(6), int64(2), object(1)
# memory usage: 468.8+ KB

# %% [markdown]
# <div class="alert alert-dark">
#
# Дублей в данных нет (после использования метода `drop_duplicates()` количество строк не уменьшилось)

# %%
df = df.loc[:, df.notna().all(axis=0)]
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6000 entries, 0 to 499
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   was_married  6000 non-null   int64
#  1   children     6000 non-null   float64
#  2   salary       6000 non-null   float64
#  3   sex          6000 non-null   int64
#  4   age          6000 non-null   float64
#  5   profession   6000 non-null   object
#  6   home_cost    6000 non-null   float64
#  7   happyness    6000 non-null   float64
# dtypes: float64(5), int64(2), object(1)
# memory usage: 421.9+ KB

# %% [markdown]
# <div class="alert alert-dark">
#
# Удалили столбец `drive_info`, в котором были пропуски данных

# %%
# Возьмем нормальные значения, которые лежат в пределах 0,05 < p-value < 0,95

n1 = np.quantile(df["home_cost"], 0.05)
n2 = np.quantile(df["home_cost"], 0.95)
n = len(df)

df = df.drop(df.loc[df["home_cost"] < n1].index)
df = df.drop(df.loc[df["home_cost"] > n2].index)

print("Удалено ", n - len(df), " выбросов")

plt.figure(figsize=(12, 6))
# Одна строка, два столбца. Текущая ячейка - 1
plt.subplot(1, 2, 1)
plt.hist(df["home_cost"], bins=100, alpha=0.8)
plt.title("Гистограмма значений")

# Одна строка, два столбца. Текущая ячейка - 2
plt.subplot(1, 2, 2)
plt.boxplot(df["home_cost"])
plt.title("Боксплот")
# Out:
# Удалено  600  выбросов
# Text(0.5, 1.0, 'Боксплот')

# %% [markdown]
# <div class="alert alert-dark">
#
# Удалено  600  выбросов по признаку `home_cost`

# %% [markdown]
# # Проверка гипотез

# %% [markdown]
# Проверьте следующие гипотезы. Для доказательства - используйте визуализацию. (Статистические методы использовать не нужно)

# %% [markdown]
# <div class="alert alert-warning">
#
# * Правда ли женщины в среднем имеют более высокую зарплату, чем мужчины?

# %%
sns.boxplot(data=df, y="salary", color="g", x="sex")
# Out:
# <Axes: xlabel='sex', ylabel='salary'>

# %% [markdown]
# <div class="alert alert-dark">
#
# Нет, женщины в среднем имеют более низкую зарплату, чем мужчины

# %% [markdown]
# <div class="alert alert-warning">
#
# * Правда ли, что инженеры (Engineer) зарабатывают в среднем больше, чем люди из сферы развлечений (Entertainment)?

# %%
df1 = df.loc[((df.profession == "Engineer") | (df.profession == "Entertainment"))]
sns.boxplot(
    data=df1,
    y="salary",
    color="g",
    x="profession",
)
# Out:
# <Axes: xlabel='profession', ylabel='salary'>

# %% [markdown]
# <div class="alert alert-dark">
#
# Нет, инженеры (Engineer) зарабатывают в среднем меньше, чем люди из сферы развлечений (Entertainment)

# %% [markdown]
# <div class="alert alert-warning">
#
# * Правда ли, что те, у кого больше трех детей зарабатывают в среднем больше, чем те, у кого меньше или трое детей?

# %%
df1 = df.iloc[:, 1:3]

df1["c_children"] = [
    "Больше трех" if x > 3 else "Трое или меньше" for x in df1["children"]
]

sns.boxplot(data=df1, y="salary", color="g", x="c_children")
# Out:
# <Axes: xlabel='c_children', ylabel='salary'>

# %% [markdown]
# <div class="alert alert-dark">
#
# Да, правда: те, у кого больше трех детей зарабатывают в среднем больше, чем те, у кого меньше или трое детей

# %% [markdown]
# <div class="alert alert-warning">
#
# * Правда ли, что дома художники (Artist) живут в домах, которые в среднем дороже или дешевле, чем дома адвокатов (Lawyer)?

# %%
df1 = df.loc[((df.profession == "Artist") | (df.profession == "Lawyer"))]
sns.boxplot(
    data=df1,
    y="home_cost",
    color="g",
    x="profession",
)
# Out:
# <Axes: xlabel='profession', ylabel='home_cost'>

# %% [markdown]
# <div class="alert alert-dark">
#
# Нет, не правда: дома художников (Artist) в среднем дешевле, чем дома адвокатов (Lawyer)

# %% [markdown]
# <div class="alert alert-warning">
#
# * Правда ли, что недвижимость у тех, кто когда либо был в браке в среднем дороже, чем у тех, кто никогда не был в браке?

# %%
df1 = df.iloc[:, [0, 6]]
sns.boxplot(
    data=df1,
    y="home_cost",
    color="g",
    x="was_married",
)
# Out:
# <Axes: xlabel='was_married', ylabel='home_cost'>

# %% [markdown]
# <div class="alert alert-dark">
#
# Нет, не правда: недвижимость у тех, кто когда либо был в браке в среднем дешевле, чем у тех, кто никогда не был в браке

# %% [markdown]
# <div class="alert alert-warning">
#
# * Правда ли, что мужчины в среднем чаще бывают в браке, чем женщины?
#
# **Подсказка** - составьте матрицу смежности, она выглядит примерно вот так:

# %%
# ******  был в браке | не был в браке |
# мужчины      140    |      499       |
# женщины      241    |      298       |

# %%
from itertools import count

df1 = pd.pivot_table(
    df, index="sex", columns="was_married", values="salary", aggfunc="count"
)

print(df1)
df1 = df1.reset_index()

# df1 = df1.rename(columns={0: "not_married", 1: "was_married"})
# df1
# df1.info()

# sns.boxplot(
#     data=df1,
#     y="was_married",
#     color="g",
#     x="sex",
# )
# Out:
# was_married    0     1
# sex
# 0            605  1192
# 1            245  3358

# %% [markdown]
# <div class="alert alert-dark">
#
# Да, правда: мужчины в среднем чаще бывают в браке, чем женщины
